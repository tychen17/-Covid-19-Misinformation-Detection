# %%
import tweepy
import pandas as pd
import csv
import re 
import string
import preprocessor as p
 
CONSUMER_KEY = "KeE4UJ9543OPtxGQ8ay5UBiBr"
CONSUMER_SECRET = "zpDIbV6zAIE67rP7WgBIi9GrDDxm8e2lhA1zpkQbN4nA5F9wkK"
access_key = "1488885829518962688-NP4sOsum4eGUPlMcGACPoTUJPhonfZ"
access_secret = "IImQudkOqeopTXFhrj14pyOTTZreRAeeVjB82DbqnvBnq"
 
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_key, access_secret)
 
api = tweepy.API(auth,wait_on_rate_limit=True)
 
csvFile = open('C:/Users/Kelvin/Desktop/VaxMisinfoData.csv','a')
csvWriter = csv.writer(csvFile)
 
search_words = "covid vaccine"      # enter your words
new_search = search_words + " -filter:retweets"
 
for tweet in tweepy.Cursor(api.search,q=new_search,count=100,
                           lang="en",
                           since_id=0).items():
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])

# %%
test = pd.read_csv("C:/Users/Kelvin/Desktop/VaxMisinfoData.csv")
test
# Out:
#        2022-03-24 19:02:09  \
# 0      2022-03-24 19:02:05
# 1      2022-03-24 19:02:00
# 2      2022-03-24 19:02:00
# 3      2022-03-24 19:02:00
# 4      2022-03-24 19:01:48
# ...                    ...
# 57760  2022-03-16 14:20:04
# 57761  2022-03-16 14:20:01
# 57762  2022-03-16 14:20:00
# 57763  2022-03-16 14:19:50
# 57764  2022-03-16 14:19:43
#
#       b'@news4buffalo Those blood pressure medications have had decades of study\xe2\x80\x99s.\n\nWait for the Covid vaccine recalls\xe2\x80\xa6 I\xe2\x80\xa6 https://t.co/IWMSPrfTzk'  \
# 0      b'Kettering Health doctor works to build trust...
# 1      b'NOW is the time to get boosted. Household me...
# 2      b'Watch Dudu Sher-Arami, Director of Public He...
# 3      b'In partnership with the Cayuga County Health...
# 4      b'#NEW: To Counter COVID Amid Crises, Peacebui...
# ...                                                  ...
# 57760  b'WTO DG Okonjo-Iweala Welcomes Breakthrough O...
# ...
